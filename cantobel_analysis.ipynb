# %%
import pandas as pd

# %%
adamska = pd.read_csv("paper-data/Eurovision_Grand_Final_Data_2008_2024.csv")
adamska = adamska.drop(['Unnamed: 0'], axis=1)
adamska.head()
# Out:
#    idx  year  LY_SF_reciprocation  LY_SF_vote  LY_final_reciprocation  \
# 0    0  2008                  0.0    0.000000                     1.0
# 1    1  2008                  0.0    0.000000                     1.0
# 2    2  2008                  0.0    0.000000                     0.8
# 3    3  2008                  0.0    0.000000                     0.8
# 4    4  2008                  0.5    0.365854                     0.0
#
#    LY_final_vote to_country   performer                song  place_contest  \
# 0       0.878049     Russia  Dima Bilan             Believe              1
# 1       0.975610    Ukraine   Ani Lorak          Shady Lady              2
# 2       0.609756     Greece    Kalomira  Secret Combination              3
# 3       0.439024    Armenia     Sirusho          Qele, Qele              4
# 4       0.000000     Norway       Maria   Hold On Be Strong              5
#
#    ...  spectral_rms  spectral_rolloff  spectral_skewness  spectral_spread  \
# 0  ...      0.004318       2240.780518           1.414587       4993694.50
# 1  ...      0.005036       2065.456787           1.554573       6021775.00
# 2  ...      0.005337       1920.605591           1.556626       5931297.50
# 3  ...      0.004758       1600.868164           1.657006       4708476.00
# 4  ...      0.005241       1573.241455           1.743199       4112583.25
#
#    spectral_strongpeak  zerocrossingrate label_1_to_3 label_1_to_5  \
# 0             1.244766          0.084002            1            1
# 1             1.191915          0.083138            1            1
# 2             0.785189          0.083331            1            1
# 3             1.318361          0.065026            0            1
# 4             1.541387          0.060480            0            1
#
#   label_1_to_10  place_contest_scaled
# 0             1              0.000000
# 1             1              0.041667
# 2             1              0.083333
# 3             1              0.125000
# 4             1              0.166667
#
# [5 rows x 105 columns]

# %%
adamska.shape
# Out:
# (411, 105)

# %%
cantobels = pd.read_csv("song_cantobels.csv")
cantobels.head()
# Out:
#    stan_contestant  year          artist                           title  \
# 0                1  1975        Teach-In                     Ding-A-Dong
# 1                2  1975  The Swarbriggs     That's What Friends Are For
# 2                3  1975     Nicole Rieu      Et Bonjour à Toi L'artiste
# 3                4  1975     Joy Fleming  Ein Lied Kann Eine Brücke Sein
# 4                5  1975       Géraldine                             Toi
#
#                          composers                             lyricists  \
# 0                      Dick Bakker             Eddy Ouwens;Will Luikinga
# 1  Jimmy Swarbrigg;Tommy Swarbrigg                                   NaN
# 2       Jaff Barnel;Pierre Delanoë                                   NaN
# 3                   Reiner Pietsch                          Michael Holm
# 4         Bill Martin;Phil Coulter  Bill Martin;Phil Coulter;Pierre Cour
#
#                                               lyrics  \
# 0  When you feelin' all right, everything is up-t...
# 1  When you're lonely, when you're blue\nWhen you...
# 2  Et bonjour à toi, l'artiste de n'importe où\nQ...
# 3  Schau auf dein Leben\nWas hat es gegeben?\nJah...
# 4  Je me suis endormie en écoutant ta voix\nEn ou...
#
#                                youtube_url      country  cantobel_median  \
# 0  https://youtube.com/watch?v=sI78Bqp6z6g  Netherlands         1.797488
# 1  https://youtube.com/watch?v=sT34ZLdAg2U      Ireland         0.483385
# 2  https://youtube.com/watch?v=exd-6ev_Ja4       France         0.828733
# 3  https://youtube.com/watch?v=EDf9XX_p1mA      Germany        -0.951723
# 4  https://youtube.com/watch?v=5xHm_q3aKHw   Luxembourg         0.731910
#
#    cantobel_mean  cantobel_sd  cantobel_q5  cantobel_q95      rhat    ess_bulk
# 0       1.807273     0.306133     1.312974      2.316386  0.998813  901.417768
# 1       0.474818     0.321971    -0.069603      0.989021  1.003816  777.438409
# 2       0.840976     0.297375     0.373132      1.314406  0.999379  681.864163
# 3      -0.989158     0.494087    -1.835035     -0.243501  0.999985  903.089013
# 4       0.729355     0.305736     0.221830      1.248016  0.999321  770.671970

# %%
cantobels.shape
# Out:
# (1390, 16)

# %%
df = cantobels.merge(adamska, left_on=["year", "country"], right_on=["year", "to_country"], how="inner")
df.head()
# Out:
#    stan_contestant  year         artist                  title  \
# 0              783  2008           Boaz  The Fire In Your Eyes
# 1              788  2008  Elnur & Samir          Day After Day
# 2              790  2008          Maria      Hold On Be Strong
# 3              791  2008       Isis Gee               For Life
# 4              794  2008           Laka                Pokušaj
#
#             composers                      lyricists  \
# 0  Dana International  Dana International;Shai Kerem
# 1     Goher Hesenzade               Zahra Bədəlbəyli
# 2          Mira Craig                            NaN
# 3            Isis Gee                            NaN
# 4                Laka                            NaN
#
#                                             lyrics_x  \
# 0  Nafshi meyachelet litfilat halev hacham\n\nZe ...
# 1  For peace we pray\nSave us from all fears\nOh ...
# 2  Love can be hard sometimes\nYes, it can catch ...
# 3  I had no choice, perfectly clear from the star...
# 4  (Ne silazi sa čardaka)\n(Rek'o mi je pjevač La...
#
#                                youtube_url               country  \
# 0  https://youtube.com/watch?v=aWFuyxT7EXc                Israel
# 1  https://youtube.com/watch?v=6OGVL_9P5fw            Azerbaijan
# 2  https://youtube.com/watch?v=arSnpxfOD2k                Norway
# 3  https://youtube.com/watch?v=4Q8f5AueE7g                Poland
# 4  https://youtube.com/watch?v=kIRDbmpC2PI  Bosnia & Herzegovina
#
#    cantobel_median  ...  spectral_rms  spectral_rolloff  spectral_skewness  \
# 0         0.945446  ...      0.004527       1277.714355           1.911284
# 1         0.956743  ...      0.005617       1218.468750           1.587758
# 2         1.220595  ...      0.005241       1573.241455           1.743199
# 3        -0.464665  ...      0.005529       1517.397095           1.839732
# 4         0.707568  ...      0.004078       1510.549072           1.940507
#
#    spectral_spread  spectral_strongpeak  zerocrossingrate  label_1_to_3  \
# 0       4277252.50             1.320216          0.050265             0
# 1       4600169.50             1.155054          0.058005             0
# 2       4112583.25             1.541387          0.060480             0
# 3       5056450.50             1.129449          0.072717             0
# 4       4386354.00             0.838248          0.068454             0
#
#    label_1_to_5  label_1_to_10  place_contest_scaled
# 0             0              1              0.333333
# 1             0              1              0.291667
# 2             1              1              0.166667
# 3             0              0              0.958333
# 4             0              1              0.375000
#
# [5 rows x 120 columns]

# %%
df.shape
# Out:
# (386, 120)

# %% [markdown]
# shape makes sense: no data prior to 2008 from adamska, no data after 2023 from cantobels

# %% [markdown]
# now dropping all cantobels columns except cantobel_median (i chose over cantobel_mean). also dropping adamska target columns

# %%
df = df.drop(["country", "cantobel_mean", "stan_contestant", "artist", "title", "composers", "lyricists", "lyrics_x", "youtube_url", "cantobel_sd", "cantobel_q5", "cantobel_q95", "rhat", "ess_bulk"], axis=1)

# %%
df = df.drop(["place_contest", "place_contest_scaled", "label_1_to_3", "label_1_to_5", "label_1_to_10"], axis=1)

# %% [markdown]
# renaming lyrics because both dfs had lyric columns

# %%
list(df.columns)
# Out:
# ['year',
#  'cantobel_median',
#  'idx',
#  'LY_SF_reciprocation',
#  'LY_SF_vote',
#  'LY_final_reciprocation',
#  'LY_final_vote',
#  'to_country',
#  'performer',
#  'song',
#  'qualification',
#  'sf_num',
#  'running_final',
#  'running_sf',
#  'place_final',
#  'place_sf',
#  'pre_contest_url',
#  'yt_channel',
#  'upload_date',
#  'total_views',
#  'days_since_upload',
#  'yt_views_per_day',
#  'performance_url',
#  'audio_url',
#  'file_name',
#  'lyrics_y',
#  'cleaned_lyrics',
#  'lyrics_tokens',
#  'lyrics_english',
#  'lyrics_english_mix',
#  'lyrics_language',
#  'total_words',
#  'unique_words',
#  'type_token_ratio',
#  'compression_size_reduction',
#  'n_gram_repetitiveness',
#  'length(s)',
#  'bpm',
#  'beats_count',
#  'beats_loudness',
#  'danceability',
#  'onset_rate',
#  'chords_changes_rate',
#  'chords_number_rate',
#  'chords_strength',
#  'hpcp_crest',
#  'hpcp_entropy',
#  'tuning_diatonic_strength',
#  'tuning_equal_tempered_deviation',
#  'tuning_frequency',
#  'tuning_nontempered_energy_ratio',
#  'chords_key',
#  'chords_scale',
#  'key_edma_strength',
#  'key_edma_key',
#  'key_edma_scale',
#  'key_krumhansl_strength',
#  'key_krumhansl_key',
#  'key_krumhansl_scale',
#  'key_temperley_strength',
#  'key_temperley_key',
#  'key_temperley_scale',
#  'average_loudness',
#  'barkbands_crest',
#  'barkbands_flatness_db',
#  'barkbands_kurtosis',
#  'barkbands_skewness',
#  'barkbands_spread',
#  'dissonance',
#  'dynamic_complexity',
#  'erbbands_crest',
#  'erbbands_flatness_db',
#  'erbbands_kurtosis',
#  'erbbands_skewness',
#  'erbbands_spread',
#  'hfc',
#  'loudness_ebu128_int',
#  'loudness_ebu128_range',
#  'melbands_crest',
#  'melbands_flatness_db',
#  'melbands_kurtosis',
#  'melbands_skewness',
#  'melbands_spread',
#  'pitch_salience',
#  'spectral_centroid',
#  'spectral_complexity',
#  'spectral_decrease',
#  'spectral_energy',
#  'spectral_energyband_high',
#  'spectral_energyband_low',
#  'spectral_energyband_middle_high',
#  'spectral_energyband_middle_low',
#  'spectral_entropy',
#  'spectral_flux',
#  'spectral_kurtosis',
#  'spectral_rms',
#  'spectral_rolloff',
#  'spectral_skewness',
#  'spectral_spread',
#  'spectral_strongpeak',
#  'zerocrossingrate']

# %%
df = df.rename(columns={"lyrics_y": "lyrics"})

# %%
list(df.columns)
# Out:
# ['year',
#  'cantobel_median',
#  'idx',
#  'LY_SF_reciprocation',
#  'LY_SF_vote',
#  'LY_final_reciprocation',
#  'LY_final_vote',
#  'to_country',
#  'performer',
#  'song',
#  'qualification',
#  'sf_num',
#  'running_final',
#  'running_sf',
#  'place_final',
#  'place_sf',
#  'pre_contest_url',
#  'yt_channel',
#  'upload_date',
#  'total_views',
#  'days_since_upload',
#  'yt_views_per_day',
#  'performance_url',
#  'audio_url',
#  'file_name',
#  'lyrics',
#  'cleaned_lyrics',
#  'lyrics_tokens',
#  'lyrics_english',
#  'lyrics_english_mix',
#  'lyrics_language',
#  'total_words',
#  'unique_words',
#  'type_token_ratio',
#  'compression_size_reduction',
#  'n_gram_repetitiveness',
#  'length(s)',
#  'bpm',
#  'beats_count',
#  'beats_loudness',
#  'danceability',
#  'onset_rate',
#  'chords_changes_rate',
#  'chords_number_rate',
#  'chords_strength',
#  'hpcp_crest',
#  'hpcp_entropy',
#  'tuning_diatonic_strength',
#  'tuning_equal_tempered_deviation',
#  'tuning_frequency',
#  'tuning_nontempered_energy_ratio',
#  'chords_key',
#  'chords_scale',
#  'key_edma_strength',
#  'key_edma_key',
#  'key_edma_scale',
#  'key_krumhansl_strength',
#  'key_krumhansl_key',
#  'key_krumhansl_scale',
#  'key_temperley_strength',
#  'key_temperley_key',
#  'key_temperley_scale',
#  'average_loudness',
#  'barkbands_crest',
#  'barkbands_flatness_db',
#  'barkbands_kurtosis',
#  'barkbands_skewness',
#  'barkbands_spread',
#  'dissonance',
#  'dynamic_complexity',
#  'erbbands_crest',
#  'erbbands_flatness_db',
#  'erbbands_kurtosis',
#  'erbbands_skewness',
#  'erbbands_spread',
#  'hfc',
#  'loudness_ebu128_int',
#  'loudness_ebu128_range',
#  'melbands_crest',
#  'melbands_flatness_db',
#  'melbands_kurtosis',
#  'melbands_skewness',
#  'melbands_spread',
#  'pitch_salience',
#  'spectral_centroid',
#  'spectral_complexity',
#  'spectral_decrease',
#  'spectral_energy',
#  'spectral_energyband_high',
#  'spectral_energyband_low',
#  'spectral_energyband_middle_high',
#  'spectral_energyband_middle_low',
#  'spectral_entropy',
#  'spectral_flux',
#  'spectral_kurtosis',
#  'spectral_rms',
#  'spectral_rolloff',
#  'spectral_skewness',
#  'spectral_spread',
#  'spectral_strongpeak',
#  'zerocrossingrate']

# %%
df.head()
# Out:
#    year  cantobel_median  idx  LY_SF_reciprocation  LY_SF_vote  \
# 0  2008         0.945446    8                  0.0    0.146341
# 1  2008         0.956743    7                  0.0    0.000000
# 2  2008         1.220595    4                  0.5    0.365854
# 3  2008        -0.464665   23                  0.6    0.463415
# 4  2008         0.707568    9                  0.0    0.000000
#
#    LY_final_reciprocation  LY_final_vote            to_country      performer  \
# 0                     0.0       0.000000                Israel           Boaz
# 1                     0.0       0.000000            Azerbaijan  Elnur & Samir
# 2                     0.0       0.000000                Norway          Maria
# 3                     0.0       0.000000                Poland       Isis Gee
# 4                     0.4       0.414634  Bosnia & Herzegovina           Laka
#
#                     song  ...  spectral_energyband_middle_low  \
# 0  The Fire In Your Eyes  ...                        0.011821
# 1          Day After Day  ...                        0.013982
# 2      Hold On Be Strong  ...                        0.014590
# 3               For Life  ...                        0.015706
# 4                Pokušaj  ...                        0.008830
#
#    spectral_entropy  spectral_flux  spectral_kurtosis  spectral_rms  \
# 0          7.141312       0.064785           7.046309      0.004527
# 1          7.561615       0.107698           4.785693      0.005617
# 2          7.352491       0.086238           6.308065      0.005241
# 3          7.359253       0.086116           5.471573      0.005529
# 4          7.362102       0.068248           7.567697      0.004078
#
#    spectral_rolloff spectral_skewness spectral_spread spectral_strongpeak  \
# 0       1277.714355          1.911284      4277252.50            1.320216
# 1       1218.468750          1.587758      4600169.50            1.155054
# 2       1573.241455          1.743199      4112583.25            1.541387
# 3       1517.397095          1.839732      5056450.50            1.129449
# 4       1510.549072          1.940507      4386354.00            0.838248
#
#    zerocrossingrate
# 0          0.050265
# 1          0.058005
# 2          0.060480
# 3          0.072717
# 4          0.068454
#
# [5 rows x 101 columns]

# %% [markdown]
# should have 101 cols: 105 (adamska) + 16 (cantobels) - 1 (they share year column) = 120
# 120 - 14 (all cantobel cols except year (shared) and cantobel_median) = 106
# 106 - 5 (old target cols in adamska) = 101

# %% [markdown]
# ## 1. Prepare the dataset
# - load data
# - create additional features by joining key and scale
# - change data type of categorical features & encode labels

# %%
print(f"shape before preparation: {df.shape}")
#create key+scale features
df['chords_key_scale'] = df['chords_key'] + "_" + df['chords_scale']
df['edma_key_scale'] = df['key_edma_key'] + "_" + df['key_edma_scale']
df['krumhansl_key_scale'] = df['key_krumhansl_key'] + "_" + df['key_krumhansl_scale']
df['temperley_key_scale'] = df['key_temperley_key'] + "_" + df['key_temperley_scale']


# Convert to categorical data type
df['chords_key'] = df['chords_key'].astype('category')
df['chords_scale'] = df['chords_scale'].astype('category')
df['chords_key_scale'] = df['chords_key_scale'].astype('category')

df['key_edma_key'] = df['key_edma_key'].astype('category')
df['key_edma_scale'] = df['key_edma_scale'].astype('category')
df['edma_key_scale'] = df['edma_key_scale'].astype('category')

df['key_krumhansl_key'] = df['key_krumhansl_key'].astype('category')
df['key_krumhansl_scale'] = df['key_krumhansl_scale'].astype('category')
df['krumhansl_key_scale'] = df['krumhansl_key_scale'].astype('category')

df['key_temperley_key'] = df['key_temperley_key'].astype('category')
df['key_temperley_scale'] = df['key_temperley_scale'].astype('category')
df['temperley_key_scale'] = df['temperley_key_scale'].astype('category')

df['to_country'] = df['to_country'].astype('category')
df['lyrics_english'] = df['lyrics_english'].astype('category')
df['lyrics_english_mix'] = df['lyrics_english_mix'].astype('category')

#label encoder for categorical features
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()  # 'winner', 'top3'
cols = ['to_country','chords_key', 'chords_scale', 'chords_key_scale', 'key_edma_key', 'key_edma_scale',
        'edma_key_scale', 'key_krumhansl_key', 'key_krumhansl_scale', 'krumhansl_key_scale', 'key_temperley_key',
        'key_temperley_scale', 'temperley_key_scale', 'lyrics_english','lyrics_english_mix']

for col in cols:
    df[col] = le.fit_transform(df[col])

#preview data
df.head()
# Out:
# shape before preparation: (386, 101)
#    year  cantobel_median  idx  LY_SF_reciprocation  LY_SF_vote  \
# 0  2008         0.945446    8                  0.0    0.146341
# 1  2008         0.956743    7                  0.0    0.000000
# 2  2008         1.220595    4                  0.5    0.365854
# 3  2008        -0.464665   23                  0.6    0.463415
# 4  2008         0.707568    9                  0.0    0.000000
#
#    LY_final_reciprocation  LY_final_vote  to_country      performer  \
# 0                     0.0       0.000000          22           Boaz
# 1                     0.0       0.000000           4  Elnur & Samir
# 2                     0.0       0.000000          31          Maria
# 3                     0.0       0.000000          32       Isis Gee
# 4                     0.4       0.414634           7           Laka
#
#                     song  ...  spectral_rms  spectral_rolloff  \
# 0  The Fire In Your Eyes  ...      0.004527       1277.714355
# 1          Day After Day  ...      0.005617       1218.468750
# 2      Hold On Be Strong  ...      0.005241       1573.241455
# 3               For Life  ...      0.005529       1517.397095
# 4                Pokušaj  ...      0.004078       1510.549072
#
#    spectral_skewness  spectral_spread  spectral_strongpeak  zerocrossingrate  \
# 0           1.911284       4277252.50             1.320216          0.050265
# 1           1.587758       4600169.50             1.155054          0.058005
# 2           1.743199       4112583.25             1.541387          0.060480
# 3           1.839732       5056450.50             1.129449          0.072717
# 4           1.940507       4386354.00             0.838248          0.068454
#
#   chords_key_scale edma_key_scale krumhansl_key_scale  temperley_key_scale
# 0               19             19                  19                   19
# 1               17              4                   4                   17
# 2                9              9                   9                    9
# 3                4              4                   4                    4
# 4               14             14                  14                   14
#
# [5 rows x 105 columns]

# %% [markdown]
# ----------------------------------------
# Split dataset into training and testing.
#
# **Select year for testing!** for example, 2018

# %%
train_data = df[df['year'] != 2018].reset_index(drop=True)
test_data = df[df['year'] == 2018].reset_index(drop=True)

# %% [markdown]
# ## 2. Dimensionality Reduction for audio features
#
# Principal Component Analysis is implemented, number of components determined with requirement of 95% of variance explained.
# PCA transformed features replace the original subsets in the dataset.

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

def apply_pca_and_integrate(df_train, df_test, feature_subsets, subset_names):

    def determine_pca_components(data, features):
        """Determine the number of PCA components for 95% variance explained."""
        scaler = StandardScaler()
        scaled_data = scaler.fit_transform(data[features])
        pca = PCA()
        pca.fit(scaled_data)
        cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
        num_components = np.argmax(cumulative_variance >= 0.95) + 1
        print(num_components)
        return num_components, scaler, pca

    for subset, name in zip(feature_subsets, subset_names):
        # Determine number of components for training data
        num_components, scaler, pca = determine_pca_components(df_train, subset)

        # Apply PCA to training data
        train_scaled = scaler.transform(df_train[subset])
        train_pca = pca.transform(train_scaled)[:, :num_components]
        train_pca_columns = [f'{name}_PC{j+1}' for j in range(num_components)]
        train_pca_df = pd.DataFrame(train_pca, columns=train_pca_columns, index=df_train.index)

        # Apply PCA to testing data
        test_scaled = scaler.transform(df_test[subset])
        test_pca = pca.transform(test_scaled)[:, :num_components]
        test_pca_columns = [f'{name}_PC{j+1}' for j in range(num_components)]
        test_pca_df = pd.DataFrame(test_pca, columns=test_pca_columns, index=df_test.index)

        # Remove original features and add PCA components
        df_train = df_train.drop(columns=subset).join(train_pca_df)
        df_test = df_test.drop(columns=subset).join(test_pca_df)

    return df_train, df_test


feature_subsets = [
     ['barkbands_crest', 'barkbands_flatness_db', 'barkbands_kurtosis',
      'barkbands_skewness', 'barkbands_spread'],  # Barkbands
     ['erbbands_crest', 'erbbands_flatness_db', 'erbbands_kurtosis',
      'erbbands_skewness', 'erbbands_spread'],  # Erbbands
     ['melbands_crest', 'melbands_flatness_db', 'melbands_kurtosis',
      'melbands_skewness', 'melbands_spread'],  # Melbands 3
     ['spectral_centroid','spectral_complexity','spectral_decrease','spectral_energy',
      'spectral_energyband_high','spectral_energyband_low','spectral_energyband_middle_high',
      'spectral_energyband_middle_low','spectral_entropy','spectral_flux','spectral_kurtosis',
      'spectral_rms','spectral_rolloff','spectral_skewness','spectral_spread','spectral_strongpeak']  # Spectral
 ]

subset_names = ['barkbands', 'erbbands', 'melbands', 'spectral']

df_train, df_test = apply_pca_and_integrate(train_data, test_data, feature_subsets, subset_names)
print(df_train.shape)
print(df_test.shape)
# Out:
# 4
# 4
# 3
# 7
# (360, 92)
# (26, 92)

# %% [markdown]
# ## 3. Prepare and Normalise Data

# %%
#TRAIN
X_train = df_train[['LY_SF_vote', 'yt_views_per_day', 'LY_final_reciprocation', 'hpcp_crest', 'erbbands_PC1', 'hpcp_entropy', 'beats_loudness',
 'running_final', 'chords_scale', 'LY_final_vote', 'length(s)', 'to_country', 'dynamic_complexity', 'barkbands_PC4',
 'loudness_ebu128_range', 'spectral_PC1', 'LY_SF_reciprocation', 'average_loudness', 'danceability']]

X_train_df = X_train
y_train = df_train['cantobel_median']


#TEST
X_test = df_test[['LY_SF_vote', 'yt_views_per_day', 'LY_final_reciprocation', 'hpcp_crest', 'erbbands_PC1', 'hpcp_entropy', 'beats_loudness',
 'running_final', 'chords_scale', 'LY_final_vote', 'length(s)', 'to_country', 'dynamic_complexity', 'barkbands_PC4',
 'loudness_ebu128_range', 'spectral_PC1', 'LY_SF_reciprocation', 'average_loudness', 'danceability']]

X_test_df = X_test
y_test = df_test['cantobel_median']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#all data
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
''' import AutoML class from flaml package '''
from flaml import AutoML
automl = AutoML()

settings = {
    "time_budget": 120,  # total running time in seconds
    "metric": 'r2',  # primary metrics for regression can be chosen from: ['mae','mse','r2','rmse','mape']
    "estimator_list": ['xgboost'],  # list of ML learners; we tune xgboost in this example
    "task": 'regression',  # task type
    "log_file_name": 'yt_contest.log',  # flaml log file
}

# %%
automl.fit(X_train=X_train, y_train=y_train, **settings)
# Out:
# [flaml.automl.logger: 07-02 15:17:30] {2375} INFO - task = regression
# [flaml.automl.logger: 07-02 15:17:30] {2386} INFO - Evaluation method: cv
# [flaml.automl.logger: 07-02 15:17:30] {2489} INFO - Minimizing error metric: 1-r2
# [flaml.automl.logger: 07-02 15:17:30] {2606} INFO - List of ML learners in AutoML Run: ['xgboost']
# [flaml.automl.logger: 07-02 15:17:30] {2911} INFO - iteration 0, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:31] {3046} INFO - Estimated sufficient time budget=6304s. Estimated necessary time budget=6s.
# [flaml.automl.logger: 07-02 15:17:31] {3097} INFO -  at 0.6s,	estimator xgboost's best error=9.5252e-01,	best estimator xgboost's best error=9.5252e-01
# [flaml.automl.logger: 07-02 15:17:31] {2911} INFO - iteration 1, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:31] {3097} INFO -  at 1.0s,	estimator xgboost's best error=9.5252e-01,	best estimator xgboost's best error=9.5252e-01
# [flaml.automl.logger: 07-02 15:17:31] {2911} INFO - iteration 2, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:32] {3097} INFO -  at 1.3s,	estimator xgboost's best error=9.0125e-01,	best estimator xgboost's best error=9.0125e-01
# [flaml.automl.logger: 07-02 15:17:32] {2911} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:32] {3097} INFO -  at 1.4s,	estimator xgboost's best error=9.0125e-01,	best estimator xgboost's best error=9.0125e-01
# [flaml.automl.logger: 07-02 15:17:32] {2911} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:33] {3097} INFO -  at 2.6s,	estimator xgboost's best error=9.0125e-01,	best estimator xgboost's best error=9.0125e-01
# [flaml.automl.logger: 07-02 15:17:33] {2911} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:34] {3097} INFO -  at 3.4s,	estimator xgboost's best error=9.0125e-01,	best estimator xgboost's best error=9.0125e-01
# [flaml.automl.logger: 07-02 15:17:34] {2911} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:35] {3097} INFO -  at 4.3s,	estimator xgboost's best error=9.0125e-01,	best estimator xgboost's best error=9.0125e-01
# [flaml.automl.logger: 07-02 15:17:35] {2911} INFO - iteration 7, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:35] {3097} INFO -  at 4.6s,	estimator xgboost's best error=9.0125e-01,	best estimator xgboost's best error=9.0125e-01
# [flaml.automl.logger: 07-02 15:17:35] {2911} INFO - iteration 8, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:35] {3097} INFO -  at 4.8s,	estimator xgboost's best error=9.0125e-01,	best estimator xgboost's best error=9.0125e-01
# [flaml.automl.logger: 07-02 15:17:35] {2911} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:36] {3097} INFO -  at 5.4s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:36] {2911} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:36] {3097} INFO -  at 5.8s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:36] {2911} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:37] {3097} INFO -  at 6.7s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:37] {2911} INFO - iteration 12, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:38] {3097} INFO -  at 7.1s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:38] {2911} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:38] {3097} INFO -  at 7.5s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:38] {2911} INFO - iteration 14, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:38] {3097} INFO -  at 7.6s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:38] {2911} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:39] {3097} INFO -  at 8.1s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:39] {2911} INFO - iteration 16, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:39] {3097} INFO -  at 8.5s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:39] {2911} INFO - iteration 17, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:39] {3097} INFO -  at 8.7s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:39] {2911} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:40] {3097} INFO -  at 9.1s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:40] {2911} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:40] {3097} INFO -  at 9.5s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:40] {2911} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:40] {3097} INFO -  at 9.9s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:40] {2911} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:41] {3097} INFO -  at 10.2s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:41] {2911} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:41] {3097} INFO -  at 10.5s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:41] {2911} INFO - iteration 23, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:41] {3097} INFO -  at 10.8s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:41] {2911} INFO - iteration 24, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:41] {3097} INFO -  at 11.0s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:41] {2911} INFO - iteration 25, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:42] {3097} INFO -  at 11.1s,	estimator xgboost's best error=8.6630e-01,	best estimator xgboost's best error=8.6630e-01
# [flaml.automl.logger: 07-02 15:17:42] {2911} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:43] {3097} INFO -  at 12.1s,	estimator xgboost's best error=8.5299e-01,	best estimator xgboost's best error=8.5299e-01
# [flaml.automl.logger: 07-02 15:17:43] {2911} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:43] {3097} INFO -  at 12.5s,	estimator xgboost's best error=8.5299e-01,	best estimator xgboost's best error=8.5299e-01
# [flaml.automl.logger: 07-02 15:17:43] {2911} INFO - iteration 28, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:43] {3097} INFO -  at 13.0s,	estimator xgboost's best error=8.5299e-01,	best estimator xgboost's best error=8.5299e-01
# [flaml.automl.logger: 07-02 15:17:43] {2911} INFO - iteration 29, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:44] {3097} INFO -  at 13.3s,	estimator xgboost's best error=8.5299e-01,	best estimator xgboost's best error=8.5299e-01
# [flaml.automl.logger: 07-02 15:17:44] {2911} INFO - iteration 30, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:45] {3097} INFO -  at 14.2s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:17:45] {2911} INFO - iteration 31, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:46] {3097} INFO -  at 15.7s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:17:46] {2911} INFO - iteration 32, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:47] {3097} INFO -  at 16.1s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:17:47] {2911} INFO - iteration 33, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:48] {3097} INFO -  at 17.2s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:17:48] {2911} INFO - iteration 34, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:49] {3097} INFO -  at 18.7s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:17:49] {2911} INFO - iteration 35, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:51] {3097} INFO -  at 20.8s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:17:51] {2911} INFO - iteration 36, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:52] {3097} INFO -  at 21.3s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:17:52] {2911} INFO - iteration 37, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:54] {3097} INFO -  at 23.8s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:17:54] {2911} INFO - iteration 38, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:55] {3097} INFO -  at 24.5s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:17:55] {2911} INFO - iteration 39, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:56] {3097} INFO -  at 25.5s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:17:56] {2911} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:56] {3097} INFO -  at 26.0s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:17:56] {2911} INFO - iteration 41, current learner xgboost
# [flaml.automl.logger: 07-02 15:17:59] {3097} INFO -  at 28.6s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:17:59] {2911} INFO - iteration 42, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:04] {3097} INFO -  at 33.9s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:04] {2911} INFO - iteration 43, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:05] {3097} INFO -  at 34.8s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:05] {2911} INFO - iteration 44, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:06] {3097} INFO -  at 35.8s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:06] {2911} INFO - iteration 45, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:08] {3097} INFO -  at 37.9s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:08] {2911} INFO - iteration 46, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:12] {3097} INFO -  at 41.3s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:12] {2911} INFO - iteration 47, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:14] {3097} INFO -  at 43.3s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:14] {2911} INFO - iteration 48, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:15] {3097} INFO -  at 44.4s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:15] {2911} INFO - iteration 49, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:16] {3097} INFO -  at 45.7s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:16] {2911} INFO - iteration 50, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:18] {3097} INFO -  at 47.3s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:18] {2911} INFO - iteration 51, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:20] {3097} INFO -  at 49.6s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:20] {2911} INFO - iteration 52, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:21] {3097} INFO -  at 50.3s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:21] {2911} INFO - iteration 53, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:22] {3097} INFO -  at 51.9s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:22] {2911} INFO - iteration 54, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:27] {3097} INFO -  at 56.2s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:27] {2911} INFO - iteration 55, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:29] {3097} INFO -  at 58.4s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:29] {2911} INFO - iteration 56, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:30] {3097} INFO -  at 59.6s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:30] {2911} INFO - iteration 57, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:32] {3097} INFO -  at 61.6s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:32] {2911} INFO - iteration 58, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:32] {3097} INFO -  at 61.9s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:32] {2911} INFO - iteration 59, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:33] {3097} INFO -  at 62.6s,	estimator xgboost's best error=8.3014e-01,	best estimator xgboost's best error=8.3014e-01
# [flaml.automl.logger: 07-02 15:18:33] {2911} INFO - iteration 60, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:34] {3097} INFO -  at 63.6s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:34] {2911} INFO - iteration 61, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:35] {3097} INFO -  at 64.3s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:35] {2911} INFO - iteration 62, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:37] {3097} INFO -  at 66.5s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:37] {2911} INFO - iteration 63, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:38] {3097} INFO -  at 67.6s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:38] {2911} INFO - iteration 64, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:39] {3097} INFO -  at 68.8s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:39] {2911} INFO - iteration 65, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:40] {3097} INFO -  at 69.5s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:40] {2911} INFO - iteration 66, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:44] {3097} INFO -  at 73.8s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:44] {2911} INFO - iteration 67, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:46] {3097} INFO -  at 75.2s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:46] {2911} INFO - iteration 68, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:47] {3097} INFO -  at 76.4s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:47] {2911} INFO - iteration 69, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:50] {3097} INFO -  at 79.6s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:50] {2911} INFO - iteration 70, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:50] {3097} INFO -  at 79.9s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:50] {2911} INFO - iteration 71, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:52] {3097} INFO -  at 82.0s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:52] {2911} INFO - iteration 72, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:53] {3097} INFO -  at 82.8s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:53] {2911} INFO - iteration 73, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:55] {3097} INFO -  at 84.4s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:55] {2911} INFO - iteration 74, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:56] {3097} INFO -  at 85.4s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:56] {2911} INFO - iteration 75, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:57] {3097} INFO -  at 86.5s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:57] {2911} INFO - iteration 76, current learner xgboost
# [flaml.automl.logger: 07-02 15:18:59] {3097} INFO -  at 88.8s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:18:59] {2911} INFO - iteration 77, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:00] {3097} INFO -  at 89.8s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:00] {2911} INFO - iteration 78, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:02] {3097} INFO -  at 91.5s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:02] {2911} INFO - iteration 79, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:03] {3097} INFO -  at 92.6s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:03] {2911} INFO - iteration 80, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:05] {3097} INFO -  at 94.3s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:05] {2911} INFO - iteration 81, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:05] {3097} INFO -  at 94.9s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:05] {2911} INFO - iteration 82, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:08] {3097} INFO -  at 97.1s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:08] {2911} INFO - iteration 83, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:08] {3097} INFO -  at 97.9s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:08] {2911} INFO - iteration 84, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:10] {3097} INFO -  at 99.7s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:10] {2911} INFO - iteration 85, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:11] {3097} INFO -  at 100.5s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:11] {2911} INFO - iteration 86, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:13] {3097} INFO -  at 102.9s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:13] {2911} INFO - iteration 87, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:15] {3097} INFO -  at 104.6s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:15] {2911} INFO - iteration 88, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:16] {3097} INFO -  at 105.6s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:16] {2911} INFO - iteration 89, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:17] {3097} INFO -  at 106.9s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:17] {2911} INFO - iteration 90, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:19] {3097} INFO -  at 108.1s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:19] {2911} INFO - iteration 91, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:21] {3097} INFO -  at 110.3s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:21] {2911} INFO - iteration 92, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:22] {3097} INFO -  at 111.5s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:22] {2911} INFO - iteration 93, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:23] {3097} INFO -  at 112.7s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:23] {2911} INFO - iteration 94, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:24] {3097} INFO -  at 113.8s,	estimator xgboost's best error=8.2618e-01,	best estimator xgboost's best error=8.2618e-01
# [flaml.automl.logger: 07-02 15:19:24] {2911} INFO - iteration 95, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:26] {3097} INFO -  at 115.7s,	estimator xgboost's best error=8.2191e-01,	best estimator xgboost's best error=8.2191e-01
# [flaml.automl.logger: 07-02 15:19:26] {2911} INFO - iteration 96, current learner xgboost
# [flaml.automl.logger: 07-02 15:19:29] {3097} INFO -  at 118.4s,	estimator xgboost's best error=8.2191e-01,	best estimator xgboost's best error=8.2191e-01
# [flaml.automl.logger: 07-02 15:19:29] {3359} INFO - retrain xgboost for 0.1s
# [flaml.automl.logger: 07-02 15:19:29] {3362} INFO - retrained model: XGBRegressor(base_score=None, booster=None, callbacks=[],
#              colsample_bylevel=np.float64(0.8298115767292761),
#              colsample_bynode=None,
#              colsample_bytree=np.float64(0.938486490665451), device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None,
#              grow_policy='lossguide', importance_type=None,
#              interaction_constraints=None,
#              learning_rate=np.float64(0.23367879748018888), max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=0, max_leaves=12,
#              min_child_weight=np.float64(1.4102244268812896), missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=40,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 07-02 15:19:29] {2636} INFO - fit succeeded
# [flaml.automl.logger: 07-02 15:19:29] {2637} INFO - Time taken to find the best model: 115.67626905441284

# %%
# retrieve best config
print('Best hyperparmeter config:', automl.best_config)
print('Best r2 on validation data: {0:.4g}'.format(1 - automl.best_loss))
print('Training duration of best run: {0:.4g} s'.format(automl.best_config_train_time))
#automl.model.estimator
# Out:
# Best hyperparmeter config: {'n_estimators': 40, 'max_leaves': 12, 'min_child_weight': np.float64(1.4102244268812896), 'learning_rate': np.float64(0.23367879748018888), 'subsample': np.float64(0.9118712440116773), 'colsample_bylevel': np.float64(0.8298115767292761), 'colsample_bytree': np.float64(0.938486490665451), 'reg_alpha': np.float64(0.020306423184815882), 'reg_lambda': np.float64(27.983841357354247)}
# Best r2 on validation data: 0.1781
# Training duration of best run: 0.095 s

# %%
def get_sorted_feature_importances(X_train_df, automl):

    # Get feature importances from the XGBoost model
    feature_importances = automl.model.estimator.feature_importances_

    # Create a DataFrame with feature names and their importance
    feature_importance_df = pd.DataFrame({
        'Feature': X_train_df.columns,
        'Importance': feature_importances
    })

    # Sort by importance in descending order
    feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).reset_index(drop=True)

    print("Sorted Feature Importances:")
    print(feature_importance_df)

    return feature_importance_df

sorted_features = get_sorted_feature_importances(X_train_df, automl)

# plot feature importance
import matplotlib.pyplot as plt
#plt.barh(automl.feature_names_in_, automl.feature_importances_)
#plt.figure(figsize=(20, 15))
plt.barh(X_train_df.columns, automl.model.estimator.feature_importances_)
sorted_features
# Out:
# Sorted Feature Importances:
#                    Feature  Importance
# 0         yt_views_per_day    0.095271
# 1   LY_final_reciprocation    0.095039
# 2      LY_SF_reciprocation    0.080215
# 3               LY_SF_vote    0.070028
# 4             erbbands_PC1    0.061733
# 5             chords_scale    0.055618
# 6            running_final    0.054593
# 7                length(s)    0.053201
# 8           beats_loudness    0.052525
# 9               to_country    0.049597
# 10      dynamic_complexity    0.042265
# 11           barkbands_PC4    0.039455
# 12            spectral_PC1    0.039264
# 13           LY_final_vote    0.038215
# 14        average_loudness    0.037332
# 15              hpcp_crest    0.036518
# 16   loudness_ebu128_range    0.036248
# 17            hpcp_entropy    0.031533
# 18            danceability    0.031351
#                    Feature  Importance
# 0         yt_views_per_day    0.095271
# 1   LY_final_reciprocation    0.095039
# 2      LY_SF_reciprocation    0.080215
# 3               LY_SF_vote    0.070028
# 4             erbbands_PC1    0.061733
# 5             chords_scale    0.055618
# 6            running_final    0.054593
# 7                length(s)    0.053201
# 8           beats_loudness    0.052525
# 9               to_country    0.049597
# 10      dynamic_complexity    0.042265
# 11           barkbands_PC4    0.039455
# 12            spectral_PC1    0.039264
# 13           LY_final_vote    0.038215
# 14        average_loudness    0.037332
# 15              hpcp_crest    0.036518
# 16   loudness_ebu128_range    0.036248
# 17            hpcp_entropy    0.031533
# 18            danceability    0.031351

# %%
# pickle and save the automl object
import pickle
with open('model-name.pkl', 'wb') as f:
    pickle.dump(automl, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Test Data Evaluation

# %%
# compute predictions of testing dataset
y_pred = automl.predict(X_test)
# compute different metric values on testing dataset
from flaml.ml import sklearn_metric_loss_score
print('r2', '=', round(1 - sklearn_metric_loss_score('r2', y_pred, y_test), 2))
print('mse', '=', round(sklearn_metric_loss_score('mse', y_pred, y_test), 2))
print('mae', '=', round(sklearn_metric_loss_score('mae', y_pred, y_test), 2))
# Out:
# r2 = 0.13
# mse = 0.3
# mae = 0.45

# %% [markdown]
# Train Data Evaluation

# %%
# compute predictions of testing dataset
y_pred = automl.predict(X_train)
# compute different metric values on testing dataset
from flaml.ml import sklearn_metric_loss_score
print('r2', '=', round(1 - sklearn_metric_loss_score('r2', y_pred, y_train), 2))
print('mse', '=', round(sklearn_metric_loss_score('mse', y_pred, y_train), 2))
print('mae', '=', round(sklearn_metric_loss_score('mae', y_pred, y_train), 2))
# Out:
# r2 = 0.83
# mse = 0.12
# mae = 0.26

# %% [markdown]
# ## 6. Evaluation
#
# Prediction are evaluated with R2, Average Rank Error, Spearman rank correlation coefficients

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, classification_report, confusion_matrix, roc_auc_score


def evaluate_model(model, X_train, y_train, X_val1, y_val1, classification=False, y_val1_class=None):

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_val1_pred = model.predict(X_val1)

    # Evaluate regression metrics
    def evaluate_regression(y_true, y_pred):
        mae = mean_absolute_error(y_true, y_pred)
        mse = mean_squared_error(y_true, y_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_true, y_pred)
        return {"MAE": round(mae, 2), "MSE": round(mse, 2),"RMSE": round(rmse, 2),"R2": round(r2, 2)}

    train_metrics = evaluate_regression(y_train, y_train_pred)
    val1_metrics = evaluate_regression(y_val1, y_val1_pred)

    print("Training Performance:", train_metrics)
    print("Validation 1 Performance:", val1_metrics)

    # Plot results
    plt.figure(figsize=(20, 6))

    plt.subplot(1, 2, 1)
    plt.scatter(y_train, y_train_pred, color='blue')
    plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', linewidth=2)
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.title("Training Set")

    plt.subplot(1, 2, 2)
    plt.scatter(y_val1, y_val1_pred, color='green')
    plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', linewidth=2)
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.title("Validation 1 Set")

    plt.tight_layout()
    plt.show()

    if classification:
     # Determine the thresholds
      threshold1 = np.sort(y_val1_pred)[9]

      # Label top 10 predictions as positive class
      y_val1_pred_class = np.where(y_val1_pred <= threshold1, 1, 0)

      df_val = test_data[['performer', 'song', 'to_country', 'place_contest']].reset_index(drop=True)

      df_val['Prediction'] = y_val1_pred
      df_val['Prediction-Class'] = y_val1_pred_class
      df_val['Ground-Truth'] = y_val1_class.values

      # Add "predicted_position" column based on sorted "Prediction"
      df_val = df_val.sort_values("Prediction").reset_index(drop=True)
      df_val['predicted_position'] = df_val.index + 1

      # Calculate rank similarity metrics
      from scipy.stats import spearmanr, kendalltau

    # Spearman rank correlation
      spearman_corr, spearman_pvalue = spearmanr(df_val['place_contest'], df_val['predicted_position'])

    # Kendall rank correlation
      kendall_corr, kendall_pvalue = kendalltau(df_val['place_contest'], df_val['predicted_position'])

    # Average rank error
      rank_errors = abs(df_val['place_contest'] - df_val['predicted_position'])
      average_rank_error = rank_errors.mean()

    # Evaluate regression metrics
      train_r2 = r2_score(y_train, y_train_pred)
      test_r2 = r2_score(y_val1, y_val1_pred)

    # Save metrics to a DataFrame
      metrics_df = pd.DataFrame({
          "Train R2": [round(train_r2, 2)],
          "Test R2": [round(test_r2, 2)],
          "Spearman Coefficient": [round(spearman_corr, 2)],
          "Spearman P-Value": [round(spearman_pvalue, 2)],
          "Kendall Coefficient": [round(kendall_corr, 2)],
          "Kendall P-Value": [round(kendall_pvalue, 2)],
          "Average Rank Error": [round(average_rank_error, 2)]
      })

    # Print metrics DataFrame
      print("\nMetrics:")
      print(metrics_df)

      print("\nValidation 1 Classification Report")
      print(classification_report(y_val1_class, y_val1_pred_class))
      print("Confusion Matrix:\n", confusion_matrix(y_val1_class, y_val1_pred_class))
      print("ROC AUC:", roc_auc_score(y_val1_class, y_val1_pred_class))

      print("\nRank Similarity Metrics:")
      print(f"Spearman Rank Correlation: {spearman_corr:.2f} (p-value: {spearman_pvalue:.2f})")
      print(f"Kendall Rank Correlation: {kendall_corr:.2f} (p-value: {kendall_pvalue:.2f})")
      print(f"Average Rank Error: {average_rank_error:.2f}")

      return df_val, metrics_df

# %%
evaluate_model(automl, X_train, y_train, X_test, y_test)
# Out:
# Training Performance: {'MAE': 0.26, 'MSE': 0.12, 'RMSE': np.float64(0.34), 'R2': 0.83}
# Validation 1 Performance: {'MAE': 0.45, 'MSE': 0.3, 'RMSE': np.float64(0.54), 'R2': 0.13}
